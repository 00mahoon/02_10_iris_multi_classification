# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/iris.csv', names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"])
dataset=df.copy()

Y_obj=dataset.pop("species")
X=dataset.copy()

# %%
# 문자열을 숫자로 변환
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)
Y_encoded = tf.keras.utils.to_categorical(Y) # one-hot encoding변환하는 기능

# %%
# 전체 데이터에서 학습 데이터와 테스트 데이터(0.1)로 구분
X_train1, X_test, Y_train1, Y_test = train_test_split(X, Y_encoded, test_size=0.1, shuffle=True)  ## shuffle=True로 하면 데이터를 섞어서 나눔
## 학습 셋에서 학습과 검증 데이터(0.2)로 구분
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train1, Y_train1, test_size=0.2, shuffle=True)  ## shuffle=True로 하면 데이터를 섞어서 나눔

# %%
# 모델의 설정

input_Layer = tf.keras.layers.Input(shape=(4,))
x = tf.keras.layers.Dense(16, activation='sigmoid')(input_Layer)
x = tf.keras.layers.Dense(12, activation='sigmoid')(x)
Out_Layer= tf.keras.layers.Dense(3, activation='softmax')(x)
model = tf.keras.models.Model(inputs=[input_Layer], outputs=[Out_Layer])
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 4)]               0
#
#  dense_9 (Dense)             (None, 16)                80
#
#  dense_10 (Dense)            (None, 12)                204
#
#  dense_11 (Dense)            (None, 3)                 39
#
# =================================================================
# Total params: 323 (1.26 KB)
# Trainable params: 323 (1.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 컴파일
loss=tf.keras.losses.categorical_crossentropy
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01) # 경사하강법의 방법
metrics=tf.keras.metrics.categorical_accuracy
model.compile(loss=loss,optimizer=optimizer,metrics=[metrics])

## model fit은 histoy를 반환한다. 훈련중의 발생하는 모든 정보를 담고 있는 딕셔너리.
history=model.fit(X_train, Y_train, epochs=50, batch_size=50, validation_data=(X_valid,Y_valid)) # validation_data=(X_valid,Y_valid)을 추가하여 학습시 검증을 해줌.
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 124ms/step - loss: 1.3407 - categorical_accuracy: 0.3519 - val_loss: 1.4158 - val_categorical_accuracy: 0.2963
# Epoch 2/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3285 - categorical_accuracy: 0.3519 - val_loss: 1.3988 - val_categorical_accuracy: 0.2963
# Epoch 3/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3152 - categorical_accuracy: 0.3519 - val_loss: 1.3928 - val_categorical_accuracy: 0.2963
# Epoch 4/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3095 - categorical_accuracy: 0.3519 - val_loss: 1.3809 - val_categorical_accuracy: 0.2963
# Epoch 5/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3005 - categorical_accuracy: 0.3519 - val_loss: 1.3665 - val_categorical_accuracy: 0.2963
# Epoch 6/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2889 - categorical_accuracy: 0.3519 - val_loss: 1.3564 - val_categorical_accuracy: 0.2963
# Epoch 7/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2808 - categorical_accuracy: 0.3519 - val_loss: 1.3415 - val_categorical_accuracy: 0.2963
# Epoch 8/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2689 - categorical_accuracy: 0.3519 - val_loss: 1.3254 - val_categorical_accuracy: 0.2963
# Epoch 9/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2564 - categorical_accuracy: 0.3519 - val_loss: 1.3133 - val_categorical_accuracy: 0.2963
# Epoch 10/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2465 - categorical_accuracy: 0.3519 - val_loss: 1.3006 - val_categorical_accuracy: 0.2963
# Epoch 11/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.2373 - categorical_accuracy: 0.3519 - val_loss: 1.2916 - val_categorical_accuracy: 0.2963
# Epoch 12/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.2305 - categorical_accuracy: 0.3519 - val_loss: 1.2815 - val_categorical_accuracy: 0.2963
# Epoch 13/50
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2229 - categorical_accuracy: 0.3519 - val_loss: 1.2717 - val_categorical_accuracy: 0.2963
# Epoch 14/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2154 - categorical_accuracy: 0.3519 - val_loss: 1.2647 - val_categorical_accuracy: 0.2963
# Epoch 15/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2102 - categorical_accuracy: 0.3519 - val_loss: 1.2596 - val_categorical_accuracy: 0.2963
# Epoch 16/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2062 - categorical_accuracy: 0.3519 - val_loss: 1.2467 - val_categorical_accuracy: 0.2963
# Epoch 17/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1966 - categorical_accuracy: 0.3519 - val_loss: 1.2434 - val_categorical_accuracy: 0.2593
# Epoch 18/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1939 - categorical_accuracy: 0.3519 - val_loss: 1.2352 - val_categorical_accuracy: 0.2593
# Epoch 19/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1879 - categorical_accuracy: 0.3426 - val_loss: 1.2277 - val_categorical_accuracy: 0.2593
# Epoch 20/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1823 - categorical_accuracy: 0.3241 - val_loss: 1.2230 - val_categorical_accuracy: 0.2593
# Epoch 21/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1790 - categorical_accuracy: 0.3333 - val_loss: 1.2192 - val_categorical_accuracy: 0.2593
# Epoch 22/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1765 - categorical_accuracy: 0.2963 - val_loss: 1.2155 - val_categorical_accuracy: 0.2593
# Epoch 23/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1732 - categorical_accuracy: 0.3426 - val_loss: 1.2113 - val_categorical_accuracy: 0.2593
# Epoch 24/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1697 - categorical_accuracy: 0.3333 - val_loss: 1.2051 - val_categorical_accuracy: 0.2593
# Epoch 25/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1650 - categorical_accuracy: 0.3333 - val_loss: 1.2001 - val_categorical_accuracy: 0.2593
# Epoch 26/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1614 - categorical_accuracy: 0.3056 - val_loss: 1.1942 - val_categorical_accuracy: 0.2593
# Epoch 27/50
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1575 - categorical_accuracy: 0.2870 - val_loss: 1.1930 - val_categorical_accuracy: 0.2593
# Epoch 28/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1563 - categorical_accuracy: 0.2963 - val_loss: 1.1880 - val_categorical_accuracy: 0.2593
# Epoch 29/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1526 - categorical_accuracy: 0.2963 - val_loss: 1.1845 - val_categorical_accuracy: 0.2593
# Epoch 30/50
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1497 - categorical_accuracy: 0.3426 - val_loss: 1.1819 - val_categorical_accuracy: 0.2963
# Epoch 31/50
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1478 - categorical_accuracy: 0.3519 - val_loss: 1.1787 - val_categorical_accuracy: 0.2963
# Epoch 32/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1451 - categorical_accuracy: 0.3519 - val_loss: 1.1757 - val_categorical_accuracy: 0.2963
# Epoch 33/50
# 3/3 [==============================] - 0s 35ms/step - loss: 1.1434 - categorical_accuracy: 0.3519 - val_loss: 1.1743 - val_categorical_accuracy: 0.2963
# Epoch 34/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.1421 - categorical_accuracy: 0.3519 - val_loss: 1.1718 - val_categorical_accuracy: 0.2963
# Epoch 35/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.1401 - categorical_accuracy: 0.3519 - val_loss: 1.1698 - val_categorical_accuracy: 0.2963
# Epoch 36/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.1388 - categorical_accuracy: 0.3519 - val_loss: 1.1686 - val_categorical_accuracy: 0.2963
# Epoch 37/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1378 - categorical_accuracy: 0.3519 - val_loss: 1.1647 - val_categorical_accuracy: 0.2963
# Epoch 38/50
# 3/3 [==============================] - 0s 27ms/step - loss: 1.1352 - categorical_accuracy: 0.3519 - val_loss: 1.1623 - val_categorical_accuracy: 0.2963
# Epoch 39/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1333 - categorical_accuracy: 0.3519 - val_loss: 1.1597 - val_categorical_accuracy: 0.2963
# Epoch 40/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1314 - categorical_accuracy: 0.3519 - val_loss: 1.1563 - val_categorical_accuracy: 0.2963
# Epoch 41/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1293 - categorical_accuracy: 0.3519 - val_loss: 1.1553 - val_categorical_accuracy: 0.2963
# Epoch 42/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1288 - categorical_accuracy: 0.3519 - val_loss: 1.1542 - val_categorical_accuracy: 0.2963
# Epoch 43/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1280 - categorical_accuracy: 0.3519 - val_loss: 1.1514 - val_categorical_accuracy: 0.2963
# Epoch 44/50
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1264 - categorical_accuracy: 0.3519 - val_loss: 1.1488 - val_categorical_accuracy: 0.2963
# Epoch 45/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.1247 - categorical_accuracy: 0.3519 - val_loss: 1.1478 - val_categorical_accuracy: 0.2963
# Epoch 46/50
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1239 - categorical_accuracy: 0.3519 - val_loss: 1.1462 - val_categorical_accuracy: 0.2963
# Epoch 47/50
# 3/3 [==============================] - 0s 36ms/step - loss: 1.1225 - categorical_accuracy: 0.3519 - val_loss: 1.1449 - val_categorical_accuracy: 0.2963
# Epoch 48/50
# 3/3 [==============================] - 0s 36ms/step - loss: 1.1218 - categorical_accuracy: 0.3519 - val_loss: 1.1432 - val_categorical_accuracy: 0.2963
# Epoch 49/50
# 3/3 [==============================] - 0s 45ms/step - loss: 1.1209 - categorical_accuracy: 0.3519 - val_loss: 1.1405 - val_categorical_accuracy: 0.2963
# Epoch 50/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1194 - categorical_accuracy: 0.3519 - val_loss: 1.1382 - val_categorical_accuracy: 0.2963
